# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
X = 2 * np.random.rand(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# %%
X[5]
# Out:
# array([0.81932195])

# %%
y[5]
# Out:
# array([6.07443796])

# %%
plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([0, 3, 0, 13]) #Set the x and y limits
plt.savefig("generated_data_plot for normal equation")
plt.show()

# %%
X_b = np.c_[np.ones((100, 1)), X]  # add x0 = 1 to each instance
theta_best = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
theta_best
# Out:
# array([[3.85393627],
#        [3.25482676]])

# %% [markdown]
# np.c_ is concatenating arrays along columns like array
# ([[1.        , 1.82567509],
#  [1.        , 1.50974181],
#  [1.        , 0.15423622],

# %% [markdown]
# The normal Equation is
# Q^ = inverse(XTX).XT.y

# %% [markdown]
# Now make predictions using Q^

# %%
X_new = np.array([[0], [2]])
X_new_b = np.c_[np.ones((2, 1)), X_new]  # add x0 = 1 to each instance
y_predict = X_new_b.dot(theta_best)
y_predict
# Out:
# array([[ 3.85393627],
#        [10.3635898 ]])

# %%
X_new  # 4+3*X = 4, 10
# Out:
# array([[0],
#        [2]])

# %%
plt.plot(X_new, y_predict, "r-")
plt.plot(X, y, "b.")
plt.axis([0, 2, 0, 15])
plt.show()

# %%
plt.plot(X_new, y_predict, "r-", linewidth=2, label="Predictions")
plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.legend(loc="upper left", fontsize=14)
plt.axis([0, 2, 0, 15])
plt.savefig("linear_model_predictions_plot")
plt.show()

# %% [markdown]
# ### Performing above linear Regression from Scikit Learn

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_reg = LinearRegression()
lin_reg.fit(X,y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([3.85393627]), array([[3.25482676]]))

# %%
lin_reg.predict(X_new)
# Out:
# array([[ 3.85393627],
#        [10.3635898 ]])
