# %%
#This is a preprocessing step to add degree to non linear data

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
m = 100
X = 6 * np.random.rand(m, 1) - 3
y = 0.5 * X**2 + X + 2 + np.random.randn(m, 1)

# %%
plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([-1, 10, 0, 10])
plt.savefig("quadratic_data_plot")
plt.show()

# %%
m = 100
X_new = 7 * np.random.rand(m, 1)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([3.43170408]), array([[0.86941692]]))

# %%
y_pred= lin_reg.predict(X_new)

# %%
plt.plot(X_new, y_pred, "r--")
plt.plot(X, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([-1, 10, 0, 10])
plt.savefig("quadratic_data_plot")
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly_features.fit_transform(X)
X_poly[0]
# Out:
# array([1.7006046, 2.892056 ])

# %%
plt.plot(X_poly, y, "b.")
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.axis([-3, 3, 0, 10])
plt.savefig("poly_quadratic_data_plot")
plt.show()

# %%
#Fitting Linear Regression 
lin_reg = LinearRegression()
lin_reg.fit(X_poly, y)
lin_reg.intercept_, lin_reg.coef_
# Out:
# (array([2.24936115]), array([[0.9675959 , 0.42287869]]))
